# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt

# %%
cell = mp.Vector3(60,30,0)

# %%
#Area Size in µm
n = 3.4                 # index of waveguide
w = 0.3                 # width of waveguide
r = 11                  # inner radius of ring
psrc = 0.3

# %%
c1 = mp.Cylinder(radius=r+w, material=mp.Medium(index=n),center=mp.Vector3(0,0))
c2 = mp.Cylinder(radius=r,center=mp.Vector3(0,0))

b1 = mp.Block(mp.Vector3(mp.inf,0.3,mp.inf),
                 center=mp.Vector3(0,psrc+r+w),
                 material=mp.Medium(index=n))
b2 = mp.Block(mp.Vector3(mp.inf,0.3,mp.inf),
                 center=mp.Vector3(0,-psrc-r-w),
                 material=mp.Medium(index=n))

# %%
geometry = [c1,c2,b1,b2]

# %%
# Waveguide:length,width,height - position - material

# %%
pml_layers = [mp.PML(1.0)] # perfectly matched layer (PML)
resolution = 5 #pixels per distance unit 10 pixels/µm

# %%
sources = [mp.Source(mp.ContinuousSource(frequency=0.94),
                     component=mp.Ez,
                     center=mp.Vector3(-28,psrc+r+w),
                     size=mp.Vector3(0,0.3))]

# %%
# Recall that, in Meep units, frequency is specified in units of 2πc
# which is equivalent to the inverse of the vacuum wavelength. 
# Thus, 0.15 corresponds to a vacuum wavelength of about 1/0.15=6.67 µm
# line source

# %%
sim = mp.Simulation(cell_size=cell,
                    boundary_layers=pml_layers,
                    geometry=geometry,
                    sources=sources,
                    resolution=resolution)

sim.run(mp.at_beginning(mp.output_epsilon),
        mp.to_appended("ez", mp.at_every(0.6, mp.output_efield_z)),
        until=200)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000200033 s
# Working in 2D dimensions.
# Computational cell is 60 x 30 x 0 with resolution 5
#      cylinder, center = (0,0,0)
#           radius 11.3, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (11.56,11.56,11.56)
#      cylinder, center = (0,0,0)
#           radius 11, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,11.6,0)
#           size (1e+20,0.3,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.56,11.56,11.56)
#      block, center = (0,-11.6,0)
#           size (1e+20,0.3,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.56,11.56,11.56)
# time for set_epsilon = 0.235601 s
# -----------
# creating output file "./eps-000000.00.h5"...
# creating output file "./ez.h5"...
# ...

# %%
eps_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
plt.figure()
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()

# %%
ez_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ez)
plt.figure()
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
plt.axis('off')
plt.show()
